# %%
from IPython.display import Image

# %% [markdown]
# ## conflicts

# %% [markdown]
# - 协同开发（不同开发人员）
# - 不同机器

# %%
Image('../imgs/conflicts1.png', width=500)

# %%
Image('../imgs/conflicts2.png', width=500)

# %%
Image('../imgs/conflicts3.png', width=500)

# %% [markdown]
# ## merge vs. rebase

# %%
Image('../imgs/merge.png', width=500)

# %% [markdown]
# - pull the latest changes from main branch (master branch) into the feature branch
#     - 并且会创建一个 merge commit
#     - 相当于在两个分支（main branch & feature branch）上打一个结（knot）

# %%
Image('../imgs/rebase.png', width=500)

# %% [markdown]
# - clean & straightforward commit history
#     - straightforward: linear

# %% [markdown]
# ## squash commits

# %% [markdown]
# - combine commits

# %%
Image('../imgs/squash.png', width=500)

# %% [markdown]
# ## 操作

# %%
Image('../../imgs/git-squash.png', width=500)

# %% [markdown]
# https://www.youtube.com/watch?v=V5KrD7CmO4o
# - `git checkout bug_fix`
#     - `Switched to branch 'bug_fix'`
# - `git rebase -i HEAD~3`
#     - `-i`: `interactive mode`
#     - 第一个编辑器：`pick` => `s` (squash)
#     - 第二个编辑器：将需要合并的 comments 注释掉；

# %%
Image('../../imgs/after-squash.png', width=500)

# %% [markdown]
# ## 总结

# %%
Image('../imgs/confilict-all.png', width=500)

# %%
Image('../imgs/conflict-mmap.png', width=500)

# %% [markdown]
# ## git pull config

# %% [markdown]
# > git config --list

# %% [markdown]
# - `git config pull.rebase false` # merge
#     - git pull --no-rebase
# - `git config pull.rebase true` # rebase
#     - git pull --rebase
# - `git config pull.ff only` # fast-forward only
